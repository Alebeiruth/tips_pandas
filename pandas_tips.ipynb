# %% [markdown]
# # Pandas
# Estrutura de dados

# %%
import pandas as pd

# %%
series_array = pd.Series([1,2,3,4,5], index = ['a', 'b', 'c', 'd', 'e'])
series_array
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
dataFrame_twoDimensions = {'Country':['Belgium','India','Brazil'], 'Capital':['Brussels','New Delhi','Brasilia'], 'Population':['111907','1303021','208476']}

df = pd.DataFrame(dataFrame_twoDimensions, columns= ['Country', 'Capital', 'Population'] )
df
# Out:
#    Country    Capital Population
# 0  Belgium   Brussels     111907
# 1    India  New Delhi    1303021
# 2   Brazil   Brasilia     208476

# %%
# dropar
series_array.drop(['a', 'e'])
series_array
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# dropar
df.drop('Country', axis = 1)
df
# Out:
#    Country    Capital Population
# 0  Belgium   Brussels     111907
# 1    India  New Delhi    1303021
# 2   Brazil   Brasilia     208476

# %%
# Sort & Rank

df.sort_index()
# Out:
#    Country    Capital Population
# 0  Belgium   Brussels     111907
# 1    India  New Delhi    1303021
# 2   Brazil   Brasilia     208476

# %%
df.sort_values(by = 'Capital')
# Out:
#    Country    Capital Population
# 2   Brazil   Brasilia     208476
# 0  Belgium   Brussels     111907
# 1    India  New Delhi    1303021

# %%
df.rank()
# Out:
#    Country  Capital  Population
# 0      1.0      2.0         1.0
# 1      3.0      3.0         2.0
# 2      2.0      1.0         3.0

# %%
# information

df.shape
# Out:
# (3, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Country', 'Capital', 'Population'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     3 non-null      object
#  1   Capital     3 non-null      object
#  2   Population  3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %%
df.count()
# Out:
# Country       3
# Capital       3
# Population    3
# dtype: int64

# %%
# Sumarização

df_new = {'Even': [2, 4, 6], 'Odd':[1, 3, 5] }
df_new = pd.DataFrame(df_new)
df_new
# Out:
#    Even  Odd
# 0     2    1
# 1     4    3
# 2     6    5

# %%
df_new.sum()
# Out:
# Even    12
# Odd      9
# dtype: int64

# %%
df_new.cumsum()
# Out:
#    Even  Odd
# 0     2    1
# 1     6    4
# 2    12    9

# %%
df_new.min()
# Out:
# Even    2
# Odd     1
# dtype: int64

# %%
df_new.max()
# Out:
# Even    6
# Odd     5
# dtype: int64

# %%
df_new.describe()
# Out:
#        Even  Odd
# count   3.0  3.0
# mean    4.0  3.0
# std     2.0  2.0
# min     2.0  1.0
# 25%     3.0  2.0
# 50%     4.0  3.0
# 75%     5.0  4.0
# max     6.0  5.0

# %%
df_new.mean()
# Out:
# Even    4.0
# Odd     3.0
# dtype: float64

# %%
df_new.median()
# Out:
# Even    4.0
# Odd     3.0
# dtype: float64

# %%
# Seleção
series_array['b']
# Out:
# 2

# %%
df[1:]
# Out:
#   Country    Capital Population
# 1   India  New Delhi    1303021
# 2  Brazil   Brasilia     208476

# %%
# selecionar unica coluna e linha
df.iloc[[0],[0]]
# Out:
#    Country
# 0  Belgium

# %%
df.loc[0, 'Country']
# Out:
# 'Belgium'

# %%
series_array['a'] = 6

# %%
# função lambda
df.apply(lambda x: x*2)
# Out:
#           Country             Capital      Population
# 0  BelgiumBelgium    BrusselsBrussels    111907111907
# 1      IndiaIndia  New DelhiNew Delhi  13030211303021
# 2    BrazilBrazil    BrasiliaBrasilia    208476208476

# %%
s3 = pd.Series([7, -2, 3], index=['a', 'c', 'd'])
s3
# Out:
# a    7
# c   -2
# d    3
# dtype: int64

# %%
series_array.add(s3, fill_value=0)
# Out:
# a    13.0
# b     2.0
# c     1.0
# d     7.0
# e     5.0
# dtype: float64

# %%
series_array.sub(s3, fill_value=0)
# Out:
# a   -1.0
# b    2.0
# c    5.0
# d    1.0
# e    5.0
# dtype: float64

# %%
series_array.div(s3, fill_value=4)
# Out:
# a    0.857143
# b    0.500000
# c   -1.500000
# d    1.333333
# e    1.250000
# dtype: float64

# %%
# para ler csv

pd.read_csv('file.csv')

# %%
# para escrever

df.to_csv('myDataFrame.csv')

# %%
# ler excel

pd.read_excel('file.xlsx')

# %%
# escrever excel

pd.to_excel("dir/'myDataFrame.xlsx")

# %%
# ler multiplas formas
xlsx = pd.ExcelFile('file.xls')

df = pd.read_excel(xlsx, 'Sheet1')

# %%
# ler SQL

from sqlalchemy import create_engine

engine = create_engine('sqlite:///:memory:')
pd.read_sql('SELECT * FROM my_table;', engine)
pd.read_sql_table('my_table', engine)

# %%
# escreve em SQL

pd.to_sql('myDF', engine)
